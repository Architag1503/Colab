# %% [markdown]
# <a href="https://colab.research.google.com/github/Architag1503/Colab/blob/main/HDBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import HDBSCAN
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
X , _ = make_blobs(n_samples=600 , centers=3 , cluster_std=[1.0 , 2.5 , 0.5] , random_state=40)

noise = np.random.uniform(low=-10 , high=10 , size=(50,2))
X = np.vstack([X , noise])
X
# Out:
# array([[-0.98051594, -3.70623626],
#        [-2.86326646, -9.02637223],
#        [-1.30074181, -3.68563184],
#        ...,
#        [-9.85484357, -6.26600456],
#        [-7.34483185, -5.14287289],
#        [-7.7778347 , -2.75645849]])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-0.5019626 ,  0.40215493],
#        [-0.96682981, -1.09848059],
#        [-0.5810291 ,  0.40796675],
#        ...,
#        [-2.69311001, -0.31987159],
#        [-2.07336664, -0.00307305],
#        [-2.18027875,  0.67005602]])

# %%
clusterer = HDBSCAN(min_cluster_size=5, min_samples=5)
labels = clusterer.fit_predict(X_scaled)
labels
# Out:
# array([ 2,  1,  2,  1,  1,  1,  3,  1, -1,  1,  3,  2,  3,  1,  2,  2,  3,
#         1,  3,  1,  3,  1,  3,  2,  1,  2,  1,  2,  2,  1,  2,  2, -1,  1,
#         3,  3,  1,  3,  3,  2,  1,  1, -1,  3,  2,  2,  1,  3,  2,  2,  2,
#         1,  1,  1,  2,  2,  1,  1,  1,  2, -1,  2,  2,  2,  3,  2,  1,  3,
#         1,  2,  1, -1,  2,  3,  3,  1,  3,  1,  2,  2, -1,  3,  1,  3,  1,
#         3,  2,  1,  1,  2,  2,  2,  1,  3, -1,  1,  1,  1,  1,  2,  1,  2,
#         3,  1,  3,  2,  3,  2,  1,  1,  2,  2,  3,  1,  1,  3,  2,  1,  1,
#         1,  2,  3,  3,  1,  3,  2, -1,  1,  2, -1,  1,  1,  2, -1,  2,  2,
#         3, -1,  3,  2,  3,  1,  3,  2,  3,  1,  3, -1,  1,  3,  3,  1,  1,
#         3,  3,  3, -1,  3,  2,  1,  2,  1,  2,  2,  3,  2, -1,  3,  3,  1,
#         1,  2,  2,  2,  1,  2,  1,  1,  3,  2,  1,  2,  2,  2,  3,  3,  2,
#        -1,  1,  2,  2,  1, -1,  1,  2,  1,  3,  2,  1,  2,  3,  1,  1,  1,
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_scaled[:,0], X_scaled[:,1], c=labels, cmap='viridis')
plt.title("HDBSCAN Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
clusterer.probabilities_
# Out:
# array([1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 1.        , 0.67611995, 0.        , 1.        ,
#        1.        , 0.75903227, 1.        , 1.        , 0.69668035,
#        1.        , 1.        , 0.66002987, 1.        , 1.        ,
#        1.        , 0.87786866, 1.        , 1.        , 1.        ,
#        1.        , 1.        , 1.        , 0.20095306, 0.67515272,
#        1.        , 0.89380078, 0.        , 0.51496539, 1.        ,
#        1.        , 0.79829518, 1.        , 1.        , 0.8023005 ,
#        0.94608497, 0.88643656, 0.        , 1.        , 1.        ,
#        0.65679966, 1.        , 1.        , 0.25081702, 1.        ,
#        0.96368458, 1.        , 0.92424604, 0.74383087, 1.        ,
#        1.        , 1.        , 0.25528947, 1.        , 1.        ,
#        0.        , 1.        , 0.52444143, 1.        , 1.        ,
#        0.41364179, 1.        , 0.86691523, 0.87786866, 0.50148736,
# ...
